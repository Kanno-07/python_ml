# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
from matplotlib import pyplot as plt

df = pd.read_csv("exam_data.csv")
print(df)
# Out:
#      Study Hours  Previous Exam Score  Pass/Fail
# 0       4.370861            81.889703          0
# 1       9.556429            72.165782          1
# 2       7.587945            58.571657          0
# 3       6.387926            88.827701          1
# 4       2.404168            81.083870          0
# ..           ...                  ...        ...
# 495     4.180170            45.494924          0
# 496     6.252905            95.038815          1
# 497     1.699612            48.209118          0
# 498     9.769553            97.014241          1
# 499     9.875897            66.760346          1
#
# [500 rows x 3 columns]

# %%
x = df.drop(columns=['Pass/Fail'])
y = df['Pass/Fail']

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
n = int(input("enter number of students to verify: "))
data = []
for i in range(n):
    s = int(input("Enter the Study Hours: "))
    t = int(input("Enter the Previous Exam Score: "))
    data.append([s,t])

ans = model.predict(data)
print(ans)
# Out:
# enter number of students to verify: 2
# Enter the Study Hours: 3
# Enter the Previous Exam Score: 59
# Enter the Study Hours: 3
# Enter the Previous Exam Score: 78
# [-0.01291522  0.22145941]
# C:\Users\Kanishka\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
score = model.score(x,y)
print(score)
# Out:
# 0.5320481899839037

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.15)
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
score = model.score(x_train,y_train)
print(score)
# Out:
# 0.5333314129256737

# %%
pd.crosstab(df['Study Hours'],df['Pass/Fail']).plot(kind='bar')
# Out:
# <Axes: xlabel='Study Hours'>

# %%
from sklearn.linear_model import Lasso
ans = Lasso(alpha=25, max_iter=100,tol=0.1)
ans.fit(x_train,y_train)
# Out:
# Lasso(alpha=25, max_iter=100, tol=0.1)

# %%
score = model.score(x_train,y_train)
print(score)
# Out:
# 0.5333314129256737
